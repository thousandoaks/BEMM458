# %% [markdown]
# # Lab 7. Strings and Text Data

# %% [markdown]
# ### This session will cover:
#
# 1. Subsetting strings
# 2. String methods
# 3. String formatting
# 4. Regular expressions

# %% [markdown]
# ### Lets import required libraries

# %%
import re

# %%
import pandas as pd

# %% [markdown]
# ### 7.1. Strings

# %% [markdown]
# #### In Python, a string is simply a series of characters. They are created by a set of opening and matching single or double quotes. For example,

# %%
word = 'grail'
sent = 'a scratch'

# %%
word[0]
# Out:
# 'g'

# %%
sent[6]
# Out:
# 't'

# %%
word[0:3]
# Out:
# 'gra'

# %%
word[-1]
# Out:
# 'l'

# %%
word[-4:]
# Out:
# 'rail'

# %% [markdown]
# ### 7.2. String methods with Python

# %%
sentence='this is a really long string of words'

# %%
type(sentence)
# Out:
# str

# %%
sentence.capitalize()
# Out:
# 'This is a really long string of words'

# %%
sentence.count('a')
# Out:
# 2

# %%
sentence.count('i')
# Out:
# 3

# %%
sentence.upper()
# Out:
# 'THIS IS A REALLY LONG STRING OF WORDS'

# %%
sentence.startswith('this')
# Out:
# True

# %% [markdown]
# ### 7.3. Finding patterns with python using regex

# %% [markdown]
# ### the following resource is your friend
#
# https://regex101.com/#python

# %%
## This is a regex pattern that matches digits
pattern_digits = '\d+'

# %%
names="13 Jodie Whittaker, John Hurn 12, Peter Capaldi 11, Matt Smith 10, David Tennant 9"

# %%
names
# Out:
# '13 Jodie Whittaker, John Hurn 12, Peter Capaldi 11, Matt Smith 10, David Tennant 9'

# %%
numbers = re.findall(pattern=pattern_digits, string=names)

# %%
numbers
# Out:
# ['13', '12', '11', '10', '9']

# %%
## This is a regex pattern that matches words except digits
pattern_words = '\D+'

# %%
words = re.findall(pattern=pattern_words, string=names)

# %%
words
# Out:
# [' Jodie Whittaker, John Hurn ',
#  ', Peter Capaldi ',
#  ', Matt Smith ',
#  ', David Tennant ']

# %%
pattern_u='\S*u+\S*'

# %%
words_containing_u = re.findall(pattern=pattern_u, string=names)

# %%
words_containing_u
# Out:
# ['Hurn']

# %%
pattern_Jo='\S*Jo+\S*'

# %%
words_starting_with_Jo = re.findall(pattern=pattern_Jo, string=names)

# %%
words_starting_with_Jo
# Out:
# ['Jodie', 'John']

# %% [markdown]
# ### 7.4. String methods with Pandas

# %% [markdown]
# ### Pandas offers string manipulation capabilities

# %%
hello_words= pd.Series(['hola', 'hello', 'nǐ hǎo','hallo','bonjour'], dtype="string")

# %%
hello_words
# Out:
# 0       hola
# 1      hello
# 2     nǐ hǎo
# 3      hallo
# 4    bonjour
# dtype: string

# %%
boolean_contains_a=hello_words.str.count("a")

# %%
boolean_contains_a
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# dtype: Int64

# %%
boolean_hallo=hello_words.str.match("hallo")

# %%
boolean_hallo
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# dtype: boolean

# %%
hello_words.str.upper()
# Out:
# 0       HOLA
# 1      HELLO
# 2     NǏ HǍO
# 3      HALLO
# 4    BONJOUR
# dtype: string

# %%
hello_words.str.split('l')
# Out:
# 0      [ho, a]
# 1    [he, , o]
# 2     [nǐ hǎo]
# 3    [ha, , o]
# 4    [bonjour]
# dtype: object

# %%
hello_words.str.replace('h', 'j')
# Out:
# 0       jola
# 1      jello
# 2     nǐ jǎo
# 3      jallo
# 4    bonjour
# dtype: string

# %%
hello_words.str.cat(sep=',')
# Out:
# 'hola,hello,nǐ hǎo,hallo,bonjour'

# %%
hello_words.str[0:3]
# Out:
# 0    hol
# 1    hel
# 2    nǐ
# 3    hal
# 4    bon
# dtype: string

# %%
hello_words.str[0:4]
# Out:
# 0    hola
# 1    hell
# 2    nǐ h
# 3    hall
# 4    bonj
# dtype: string

# %% [markdown]
# ### 7.5. Finding patterns with pandas using regex

# %%
numbers=pd.Series(['1', '2', '3a', '3b', '03c', '4dx'])

# %%
numbers
# Out:
# 0      1
# 1      2
# 2     3a
# 3     3b
# 4    03c
# 5    4dx
# dtype: object

# %%
## numbers is a pandas series object
type(numbers)
# Out:
# pandas.core.series.Series

# %%
pattern = r'[0-9][a-z]'

# %%
numbers.str.contains(pattern)
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5     True
# dtype: bool

# %%
numbers.str.match(pattern)
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
numbers.str.contains('\d', regex=True)
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# dtype: bool

# %%
numbers.str.contains('\D', regex=True)
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5     True
# dtype: bool

# %%
long_strings=pd.Series(['This is a really long string','13 Jodie Whittaker', 'John Hurn 12','David Lopez 34','this is a sentencce'])

# %%
long_strings
# Out:
# 0    This is a really long string
# 1              13 Jodie Whittaker
# 2                    John Hurn 12
# 3                  David Lopez 34
# 4             this is a sentencce
# dtype: object

# %%
long_strings.str.contains('\d', regex=True)
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# dtype: bool

# %% [markdown]
# ### 7.6. Filtering patterns with pandas using regex

# %% [markdown]
# ### it builds on the previous step, this time we define a filter

# %%
digit_filter=long_strings.str.contains('\d', regex=True)

# %%
long_strings[digit_filter]
# Out:
# 1    13 Jodie Whittaker
# 2          John Hurn 12
# 3        David Lopez 34
# dtype: object

# %%
type(long_strings_numbers)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### 7.7. Extract patterns with pandas using regex

# %%
long_strings
# Out:
# 0    This is a really long string
# 1              13 Jodie Whittaker
# 2                    John Hurn 12
# 3                  David Lopez 34
# 4             this is a sentencce
# dtype: object

# %%
long_strings_numbers=long_strings.str.extract(r'(\d+)', expand=False)

# %%
long_strings_numbers
# Out:
# 0    NaN
# 1     13
# 2     12
# 3     34
# 4    NaN
# dtype: object

# %%
pd.concat([long_strings, long_strings_numbers], axis=1)
# Out:
#                               0    1
# 0  This is a really long string  NaN
# 1            13 Jodie Whittaker   13
# 2                  John Hurn 12   12
# 3                David Lopez 34   34
# 4           this is a sentencce  NaN

# %% [markdown]
# # Further References:

# %% [markdown]
# #### Chapter 8 from the reference book: Pandas for Everyone. Available online at Exeter Library
