# %% [markdown]
# ## Test 1. My first data science project

# %% [markdown]
# ### In this lab you will apply the concepts and techniques developed in previous sessions. You are expected to work on the assignments on your own DURING the duration of the lab.
#
# ### You are expected to submit the code developed as well as a brief description of your findings and insights.
#
# ### This lab represents 30% of the total marking of the module¶

# %% [markdown]
# TO DO: Description of the challenge

# %% [markdown]
# ### Let's load and install some libraries

# %%
# !pip install py-openaq

# %%
import pandas as pd
import seaborn as sns
import openaq
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# ### Let's load the dataset

# %%
airQualityCities=pd.read_csv('https://raw.githubusercontent.com/thousandoaks/BEMM458_OLD/master/data/airQualityCities.csv')

# %%
airQualityCities.sample(5)
# Out:
#                 date.local                   location parameter  value  \
# 3643   2021-10-10 01:00:00                    FR04131       no2  59.90
# 8689   2021-10-07 02:00:00                    DEBE010       no2  38.10
# 964    2021-10-12 02:00:00                    DEBE051        o3  33.29
# 30837  2021-09-29 11:15:00  Anand Vihar, Delhi - DPCC        o3  21.90
# 27278  2021-09-29 21:15:00   Lodhi Road, Delhi - IITM        o3  17.55
#
#                          unit country    city                   date.utc  \
# 3643   b'\xc2\xb5g/m\xc2\xb3'      FR   Paris  2021-10-09 23:00:00+00:00
# 8689   b'\xc2\xb5g/m\xc2\xb3'      DE  Berlin  2021-10-07 00:00:00+00:00
# 964    b'\xc2\xb5g/m\xc2\xb3'      DE  Berlin  2021-10-12 00:00:00+00:00
# 30837  b'\xc2\xb5g/m\xc2\xb3'      IN   Delhi  2021-09-29 05:45:00+00:00
# 27278  b'\xc2\xb5g/m\xc2\xb3'      IN   Delhi  2021-09-29 15:45:00+00:00
#
#        coordinates.latitude  coordinates.longitude
# ...

# %%
airQualityCities.head()
# Out:
#             date.local                       location parameter  value  \
# 0  2021-10-12 23:00:00  US Diplomatic Post: New Delhi      pm25 -999.0
# 1  2021-10-12 18:00:00                Southend-on-Sea      pm10   14.0
# 2  2021-10-12 18:00:00                  London Eltham      pm25    8.0
# 3  2021-10-12 18:00:00         Tower Hamlets Roadside       no2   36.0
# 4  2021-10-12 18:00:00                  London Eltham       no2   15.0
#
#                      unit country    city                   date.utc  \
# 0  b'\xc2\xb5g/m\xc2\xb3'      IN   Delhi  2021-10-12 17:30:00+00:00
# 1  b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-10-12 17:00:00+00:00
# 2  b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-10-12 17:00:00+00:00
# 3  b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-10-12 17:00:00+00:00
# 4  b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-10-12 17:00:00+00:00
#
#    coordinates.latitude  coordinates.longitude
# 0             28.635760              77.224450
# ...

# %%
airQualityCities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37087 entries, 0 to 37086
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date.local             37087 non-null  object
#  1   location               37087 non-null  object
#  2   parameter              37087 non-null  object
#  3   value                  37087 non-null  float64
#  4   unit                   37087 non-null  object
#  5   country                37087 non-null  object
#  6   city                   37087 non-null  object
#  7   date.utc               37087 non-null  object
#  8   coordinates.latitude   37087 non-null  float64
#  9   coordinates.longitude  37087 non-null  float64
# dtypes: float64(3), object(7)
# memory usage: 2.8+ MB

# %%
airQualityCities.groupby('city').count()
# Out:
#          date.local  location  parameter  value   unit  country  date.utc  \
# city
# Beijing         300       300        300    300    300      300       300
# Berlin         2248      2248       2248   2248   2248     2248      2248
# Delhi         16265     16265      16265  16265  16265    16265     16265
# London         5772      5772       5772   5772   5772     5772      5772
# Madrid         7400      7400       7400   7400   7400     7400      7400
# Paris          5102      5102       5102   5102   5102     5102      5102
#
#          coordinates.latitude  coordinates.longitude
# city
# Beijing                   300                    300
# Berlin                   2248                   2248
# Delhi                   16265                  16265
# London                   5772                   5772
# Madrid                   7400                   7400
# Paris                    5102                   5102

# %%
airQualityCities.groupby('parameter').count()
# Out:
#            date.local  location  value   unit  country   city  date.utc  \
# parameter
# co               3248      3248   3248   3248     3248   3248      3248
# no2             10417     10417  10417  10417    10417  10417     10417
# o3               7401      7401   7401   7401     7401   7401      7401
# pm10             7206      7206   7206   7206     7206   7206      7206
# pm25             5783      5783   5783   5783     5783   5783      5783
# so2              3032      3032   3032   3032     3032   3032      3032
#
#            coordinates.latitude  coordinates.longitude
# parameter
# co                         3248                   3248
# no2                       10417                  10417
# o3                         7401                   7401
# pm10                       7206                   7206
# pm25                       5783                   5783
# so2                        3032                   3032

# %% [markdown]
# ## Question 1. Find cities with levels of O3 larger than 120 µg/m³

# %%
cities_o3 = airQualityCities [ airQualityCities['parameter'] == 'o3']

# %%
cities_o3
# Out:
#                 date.local                           location parameter  \
# 13     2021-10-12 18:00:00                  London Harlington        o3
# 14     2021-10-12 18:00:00                           Thurrock        o3
# 15     2021-10-12 18:00:00  London Haringey Priory Park South        o3
# 19     2021-10-12 18:00:00                    Southend-on-Sea        o3
# 20     2021-10-12 18:00:00                      London Eltham        o3
# ...                    ...                                ...       ...
# 37069  2021-09-28 20:15:00               Rohini, Delhi - DPCC        o3
# 37074  2021-09-28 20:15:00          NSIT Dwarka, Delhi - CPCB        o3
# 37076  2021-09-28 20:15:00           Lodhi Road, Delhi - IITM        o3
# 37080  2021-09-28 20:15:00     Dwarka-Sector 8, Delhi - DPCC         o3
# 37081  2021-09-28 20:15:00            Lodhi Road, Delhi - IMD        o3
#
#        value                    unit country    city  \
# ...

# %%
cities_o3 [ cities_o3['value'] >= 120 ] ['city']
# Out:
# 7833     Madrid
# 26683     Delhi
# 26822    Madrid
# 27279     Delhi
# 28675     Delhi
# 28868     Delhi
# 29656     Delhi
# 29718     Delhi
# 29733     Delhi
# 30080     Delhi
# 36164     Delhi
# 36327     Delhi
# 36504    Madrid
# 36559    Madrid
# Name: city, dtype: object

# %%
cities_o3 [ cities_o3['value'] >= 120 ] ['city'].unique()
# Out:
# array(['Madrid', 'Delhi'], dtype=object)

# %% [markdown]
# # My findings - there are two cities, Madrid and Delhi, which are with levels of O3 larger than 120 µg/m³.

# %% [markdown]
# ## Question 2. Which city has the cleanest air ?
# ### Tip: consider adapting the following example: https://seaborn.pydata.org/examples/grouped_boxplot.html

# %%
co = airQualityCities [airQualityCities['parameter'] == 'co']
no = airQualityCities [airQualityCities['parameter'] == 'no']
o3 = airQualityCities [airQualityCities['parameter'] == 'o3']
pm10 = airQualityCities [airQualityCities['parameter'] == 'pm10']
pm25 = airQualityCities [airQualityCities['parameter'] == 'pm25']
so2 = airQualityCities [airQualityCities['parameter'] == 'so2']

# %%
co.sample(5)
# Out:
#                 date.local                             location parameter  \
# 15975  2021-10-02 03:00:00                              ES1806A        co
# 12724  2021-10-04 07:00:00                              ES1613A        co
# 31119  2021-09-29 10:30:00              R K Puram, Delhi - DPCC        co
# 24403  2021-09-30 04:45:00  IHBAS, Dilshad Garden, Delhi - CPCB        co
# 28512  2021-09-29 18:15:00                 Bawana, Delhi - DPCC        co
#
#         value                    unit country    city  \
# 15975   400.0  b'\xc2\xb5g/m\xc2\xb3'      ES  Madrid
# 12724   400.0  b'\xc2\xb5g/m\xc2\xb3'      ES  Madrid
# 31119   300.0  b'\xc2\xb5g/m\xc2\xb3'      IN   Delhi
# 24403  1100.0  b'\xc2\xb5g/m\xc2\xb3'      IN   Delhi
# 28512  1600.0  b'\xc2\xb5g/m\xc2\xb3'      IN   Delhi
#
#                         date.utc  coordinates.latitude  coordinates.longitude
# 15975  2021-10-02 04:00:00+00:00             40.286940              -3.222220
# ...

# %%
co['value'].describe() #co value range 0~10,000
# Out:
# count     3248.000000
# mean       870.817026
# std        698.497258
# min          0.000000
# 25%        400.000000
# 50%        700.000000
# 75%       1200.000000
# max      10000.000000
# Name: value, dtype: float64

# %%
no #none
# Out:
# Empty DataFrame
# Columns: [date.local, location, parameter, value, unit, country, city, date.utc, coordinates.latitude, coordinates.longitude]
# Index: []

# %%
no['value'].describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: value, dtype: float64

# %%
o3.sample(5)
# Out:
#                 date.local  location parameter  value                    unit  \
# 9539   2021-10-06 06:00:00  Thurrock        o3   44.0  b'\xc2\xb5g/m\xc2\xb3'
# 4704   2021-10-09 11:00:00   ES1613A        o3   69.0  b'\xc2\xb5g/m\xc2\xb3'
# 17249  2021-10-01 14:00:00   ES1838A        o3   62.0  b'\xc2\xb5g/m\xc2\xb3'
# 33749  2021-09-29 00:00:00  Thurrock        o3   58.0  b'\xc2\xb5g/m\xc2\xb3'
# 1550   2021-10-11 14:00:00  Thurrock        o3   16.0  b'\xc2\xb5g/m\xc2\xb3'
#
#       country    city                   date.utc  coordinates.latitude  \
# 9539       GB  London  2021-10-06 05:00:00+00:00              51.47707
# 4704       ES  Madrid  2021-10-09 09:00:00+00:00              40.66639
# 17249      ES  Madrid  2021-10-01 12:00:00+00:00              40.59333
# 33749      GB  London  2021-09-28 23:00:00+00:00              51.47707
# 1550       GB  London  2021-10-11 13:00:00+00:00              51.47707
#
#        coordinates.longitude
# 9539                0.317969
# ...

# %%
o3.describe() #o3 value range -13 ~ 295
# Out:
#              value  coordinates.latitude  coordinates.longitude
# count  7401.000000           7401.000000            7401.000000
# mean     32.280693             39.808232              25.664501
# std      23.854093              9.504481              41.976026
# min     -13.190000             28.470691             -71.217639
# 25%      12.800000             28.674045              -3.466670
# 50%      28.900000             40.409722               0.678408
# 75%      50.000000             51.452580              77.146263
# max     295.150000             52.653269              77.315809

# %%
pm10.describe() # pm10 value range 0~3729
# Out:
#              value  coordinates.latitude  coordinates.longitude
# count  7206.000000           7206.000000            7206.000000
# mean     44.058565             39.923536              30.301654
# std      75.855744              9.750931              37.397853
# min       0.000000             28.470691              -4.396940
# 25%      11.000000             28.672342              -0.441614
# 50%      24.500000             40.421667               2.346669
# 75%      67.000000             48.891670              77.147311
# max    3728.900000             52.643525              77.315809

# %%
pm25.describe() #pm25 value range -9999~1000
# Out:
#              value  coordinates.latitude  coordinates.longitude
# count  5783.000000           5783.000000            5783.000000
# mean    -25.310794             36.977539              47.227746
# std     649.750627              9.617690              40.389564
# min   -9999.000000             28.470691              -4.274720
# 25%       8.000000             28.635760               0.070766
# 50%      19.700000             28.815329              77.101981
# 75%      33.930000             48.838603              77.224450
# max    1000.000000             52.643525             116.470000

# %%
so2.describe() #so2 range 0~174
# Out:
#              value  coordinates.latitude  coordinates.longitude
# count  3032.000000           3032.000000            3032.000000
# mean      6.906873             33.009314              56.015724
# std       7.626477              7.753987              35.079354
# min       0.000000             28.498571              -4.274720
# 25%       2.000000             28.609090               0.317969
# 50%       4.900000             28.681174              77.147311
# 75%       8.500000             40.251940              77.227234
# max     174.400000             51.477070              77.315809

# %% [markdown]
# # The value of different paremeters vary greatly.
# # If using the Grouped boxplot, the plot is hard to do visual comparision.
# # So consider drawing box plots by paremeters

# %%
airQualityCities.groupby('city').count()
# Out:
#          date.local  location  parameter  value   unit  country  date.utc  \
# city
# Beijing         300       300        300    300    300      300       300
# Berlin         2248      2248       2248   2248   2248     2248      2248
# Delhi         16265     16265      16265  16265  16265    16265     16265
# London         5772      5772       5772   5772   5772     5772      5772
# Madrid         7400      7400       7400   7400   7400     7400      7400
# Paris          5102      5102       5102   5102   5102     5102      5102
#
#          coordinates.latitude  coordinates.longitude
# city
# Beijing                   300                    300
# Berlin                   2248                   2248
# Delhi                   16265                  16265
# London                   5772                   5772
# Madrid                   7400                   7400
# Paris                    5102                   5102

# %%
# co box plot
coboxplot = sns.boxplot ( x = 'city', y = 'value', data = co)
coboxplot.set_title('co value by city')
# Out:
# Text(0.5, 1.0, 'co value by city')

# %%
# Berlin has the best co air quality

# %%
# no box plot, but no didn`t include any data, so no need to compare no between cities

# %%
# o3 box plot
o3boxplot = sns.boxplot ( x = 'city', y = 'value', data = o3)
o3boxplot.set_title('o3 value by city')
# Out:
# Text(0.5, 1.0, 'o3 value by city')

# %%
# Berlin has the best o3 air quality

# %%
# pm10 box plot
pm10boxplot = sns.boxplot ( x = 'city', y = 'value', data = pm10)
pm10boxplot.set_title('pm10 value by city')
# Out:
# Text(0.5, 1.0, 'pm10 value by city')

# %%
# Delhi have the pm10 value much higher than other cities, which affects visual comparision. 
# So add a filter on pm10, to get the best pm10 quality city

# %%
pm10Filter = pm10 [pm10['value'] <250]

# %%
pm10.describe()
# Out:
#              value  coordinates.latitude  coordinates.longitude
# count  7206.000000           7206.000000            7206.000000
# mean     44.058565             39.923536              30.301654
# std      75.855744              9.750931              37.397853
# min       0.000000             28.470691              -4.396940
# 25%      11.000000             28.672342              -0.441614
# 50%      24.500000             40.421667               2.346669
# 75%      67.000000             48.891670              77.147311
# max    3728.900000             52.643525              77.315809

# %%
pm10Filterboxplot = sns.boxplot ( x = 'city', y = 'value', data = pm10Filter)
pm10Filterboxplot.set_title('pm10 value by city')
# Out:
# Text(0.5, 1.0, 'pm10 value by city')

# %%
# London has the best pm10 air quality

# %%
# pm25 box plot
pm25boxplot = sns.boxplot ( x = 'city', y = 'value', data = pm25)
pm25boxplot.set_title('pm25 value by city')
# Out:
# Text(0.5, 1.0, 'pm25 value by city')

# %%
# Beijing have the pm25 value much lower than other cities, which affects visual comparision. 
# So add ylim in y-axis

# %%
pm25boxplot = sns.boxplot ( x = 'city', y = 'value', data = pm25)
pm25boxplot.set_title('pm25 value by city')
pm25boxplot.set_ylim(-50,150)
# Out:
# (-50.0, 150.0)

# %%
# London has the best pm25 air quality

# %%
# so2 box plot
so2boxplot = sns.boxplot ( x = 'city', y = 'value', data = so2)
so2boxplot.set_title('so2 value by city')
so2boxplot.set_ylim(-2,25)
# Out:
# (-2.0, 25.0)

# %%
# London has the best so2 air quality

# %% [markdown]
# ## My finding,
# # Berlin has the best co air quality, but London co data is missing
# # Berlin has the best o3 air quality, London is the 3rd.
# # London has the best pm10 air quality, Berlin is the 3rd.
# # London has the best pm25 air quality, Berlin is the 4th
# # London has the best so2 air quality, Berlin so2 data is missing
# # In conclusion, Londen have the cleanest air, have the best value on pm10/pm25/so2.

# %% [markdown]
# ## Question 3. Which location is the most poluted in London ?

# %%
London = airQualityCities [airQualityCities['city'] == 'London']

# %%
London.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5772 entries, 1 to 37014
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date.local             5772 non-null   object
#  1   location               5772 non-null   object
#  2   parameter              5772 non-null   object
#  3   value                  5772 non-null   float64
#  4   unit                   5772 non-null   object
#  5   country                5772 non-null   object
#  6   city                   5772 non-null   object
#  7   date.utc               5772 non-null   object
#  8   coordinates.latitude   5772 non-null   float64
#  9   coordinates.longitude  5772 non-null   float64
# dtypes: float64(3), object(7)
# memory usage: 496.0+ KB

# %%
London.head()
# Out:
#             date.local                location parameter  value  \
# 1  2021-10-12 18:00:00         Southend-on-Sea      pm10   14.0
# 2  2021-10-12 18:00:00           London Eltham      pm25    8.0
# 3  2021-10-12 18:00:00  Tower Hamlets Roadside       no2   36.0
# 4  2021-10-12 18:00:00           London Eltham       no2   15.0
# 5  2021-10-12 18:00:00       London Harlington      pm10   17.0
#
#                      unit country    city                   date.utc  \
# 1  b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-10-12 17:00:00+00:00
# 2  b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-10-12 17:00:00+00:00
# 3  b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-10-12 17:00:00+00:00
# 4  b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-10-12 17:00:00+00:00
# 5  b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-10-12 17:00:00+00:00
#
#    coordinates.latitude  coordinates.longitude
# 1             51.544206               0.678408
# 2             51.452580               0.070766
# ...

# %%
London['location'].unique()
# Out:
# array(['Southend-on-Sea', 'London Eltham', 'Tower Hamlets Roadside',
#        'London Harlington', 'Thurrock',
#        'London Haringey Priory Park South'], dtype=object)

# %%
London_co = London[London['parameter'] == 'co'] 
London_o3 = London[London['parameter'] == 'o3'] 
London_pm10 = London[London['parameter'] == 'pm10'] 
London_pm25 = London[London['parameter'] == 'pm25'] 
London_so2 = London[London['parameter'] == 'so2']

# %%
London_co
# Out:
# Empty DataFrame
# Columns: [date.local, location, parameter, value, unit, country, city, date.utc, coordinates.latitude, coordinates.longitude]
# Index: []

# %%
London_o3
# Out:
#                 date.local                           location parameter  \
# 13     2021-10-12 18:00:00                  London Harlington        o3
# 14     2021-10-12 18:00:00                           Thurrock        o3
# 15     2021-10-12 18:00:00  London Haringey Priory Park South        o3
# 19     2021-10-12 18:00:00                    Southend-on-Sea        o3
# 20     2021-10-12 18:00:00                      London Eltham        o3
# ...                    ...                                ...       ...
# 36619  2021-09-28 17:00:00  London Haringey Priory Park South        o3
# 36909  2021-09-28 16:00:00                           Thurrock        o3
# 36946  2021-09-28 16:00:00                      London Eltham        o3
# 36963  2021-09-28 16:00:00                    Southend-on-Sea        o3
# 36979  2021-09-28 16:00:00  London Haringey Priory Park South        o3
#
#        value                    unit country    city  \
# ...

# %%
London_o3.describe() # range 0~ 73
# Out:
#              value  coordinates.latitude  coordinates.longitude
# count  1567.000000           1567.000000            1567.000000
# mean     36.179387             51.512680               0.117678
# std      18.925316              0.047917               0.384631
# min       0.000000             51.452580              -0.441614
# 25%      21.000000             51.477070              -0.125254
# 50%      38.000000             51.488790               0.070766
# 75%      53.000000             51.544206               0.317969
# max      73.300000             51.584128               0.678408

# %%
London_pm10
# Out:
#                 date.local           location parameter  value  \
# 1      2021-10-12 18:00:00    Southend-on-Sea      pm10   14.0
# 5      2021-10-12 18:00:00  London Harlington      pm10   17.0
# 8      2021-10-12 18:00:00      London Eltham      pm10   13.0
# 11     2021-10-12 18:00:00           Thurrock      pm10   24.0
# 25     2021-10-12 17:00:00      London Eltham      pm10   13.0
# ...                    ...                ...       ...    ...
# 36469  2021-09-28 17:00:00    Southend-on-Sea      pm10    9.0
# 36591  2021-09-28 17:00:00      London Eltham      pm10    7.0
# 36900  2021-09-28 16:00:00    Southend-on-Sea      pm10    9.0
# 36965  2021-09-28 16:00:00           Thurrock      pm10   11.0
# 36982  2021-09-28 16:00:00      London Eltham      pm10    7.0
#
#                          unit country    city                   date.utc  \
# 1      b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-10-12 17:00:00+00:00
# ...

# %%
London_pm10.describe() # range 1~51
# Out:
#              value  coordinates.latitude  coordinates.longitude
# count  1188.000000           1188.000000            1188.000000
# mean     12.079461             51.494645               0.188329
# std       8.059035              0.033491               0.416981
# min       0.900000             51.452580              -0.441614
# 25%       7.000000             51.477070               0.070766
# 50%       9.000000             51.488790               0.317969
# 75%      14.000000             51.544206               0.678408
# max      51.000000             51.544206               0.678408

# %%
London_pm25
# Out:
#                 date.local           location parameter  value  \
# 2      2021-10-12 18:00:00      London Eltham      pm25    8.0
# 9      2021-10-12 18:00:00  London Harlington      pm25   10.0
# 12     2021-10-12 18:00:00    Southend-on-Sea      pm25    9.0
# 23     2021-10-12 17:00:00      London Eltham      pm25    8.0
# 30     2021-10-12 17:00:00  London Harlington      pm25   10.0
# ...                    ...                ...       ...    ...
# 36103  2021-09-28 18:00:00      London Eltham      pm25    3.0
# 36468  2021-09-28 17:00:00    Southend-on-Sea      pm25    4.0
# 36594  2021-09-28 17:00:00      London Eltham      pm25    3.0
# 36873  2021-09-28 16:00:00    Southend-on-Sea      pm25    4.0
# 36940  2021-09-28 16:00:00      London Eltham      pm25    3.0
#
#                          unit country    city                   date.utc  \
# 2      b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-10-12 17:00:00+00:00
# ...

# %%
London_pm25.describe() #range 0~30
# Out:
#             value  coordinates.latitude  coordinates.longitude
# count  849.000000            849.000000             849.000000
# mean     7.069494             51.501662               0.136565
# std      6.671106              0.037380               0.483715
# min      0.300000             51.452580              -0.441614
# 25%      3.000000             51.452580              -0.441614
# 50%      4.000000             51.488790               0.070766
# 75%      8.000000             51.544206               0.678408
# max     30.000000             51.544206               0.678408

# %%
London_so2
# Out:
#                 date.local  location parameter  value                    unit  \
# 10     2021-10-12 18:00:00  Thurrock       so2    1.0  b'\xc2\xb5g/m\xc2\xb3'
# 27     2021-10-12 17:00:00  Thurrock       so2    1.0  b'\xc2\xb5g/m\xc2\xb3'
# 60     2021-10-12 16:00:00  Thurrock       so2    2.0  b'\xc2\xb5g/m\xc2\xb3'
# 71     2021-10-12 15:00:00  Thurrock       so2    2.0  b'\xc2\xb5g/m\xc2\xb3'
# 104    2021-10-12 14:00:00  Thurrock       so2    1.0  b'\xc2\xb5g/m\xc2\xb3'
# ...                    ...       ...       ...    ...                     ...
# 35272  2021-09-28 20:00:00  Thurrock       so2    1.0  b'\xc2\xb5g/m\xc2\xb3'
# 35754  2021-09-28 19:00:00  Thurrock       so2    1.0  b'\xc2\xb5g/m\xc2\xb3'
# 36131  2021-09-28 18:00:00  Thurrock       so2    1.0  b'\xc2\xb5g/m\xc2\xb3'
# 36476  2021-09-28 17:00:00  Thurrock       so2    1.0  b'\xc2\xb5g/m\xc2\xb3'
# 37014  2021-09-28 16:00:00  Thurrock       so2    1.0  b'\xc2\xb5g/m\xc2\xb3'
#
# ...

# %%
London_so2.describe() #range 0~5
# Out:
#             value  coordinates.latitude  coordinates.longitude
# count  332.000000          3.320000e+02           3.320000e+02
# mean     1.596386          5.147707e+01           3.179690e-01
# std      0.796510          3.985045e-13           1.556658e-15
# min      0.100000          5.147707e+01           3.179690e-01
# 25%      1.000000          5.147707e+01           3.179690e-01
# 50%      1.000000          5.147707e+01           3.179690e-01
# 75%      2.000000          5.147707e+01           3.179690e-01
# max      5.000000          5.147707e+01           3.179690e-01

# %%
plt.figure(figsize=(12,12))
sns.set_theme(style="ticks", palette="pastel")

sns.boxplot(x="location", y="value",
            hue="parameter",
            data=London)
sns.despine(offset=10, trim=True)

# %% [markdown]
# # My findings, London Eltham is the most poluted in London.

# %% [markdown]
# ## Question 4. Plot the evolution of air polution accross time in locations in London
# ### Tip: Consider using Relplot: https://seaborn.pydata.org/generated/seaborn.relplot.html#seaborn.relplot

# %%
London['datetime'] = pd.to_datetime(London['date.utc'])
# Out:
# <ipython-input-134-a369204241c1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   London['datetime'] = pd.to_datetime(London['date.utc'])

# %%
London
# Out:
#                 date.local                           location parameter  \
# 1      2021-10-12 18:00:00                    Southend-on-Sea      pm10
# 2      2021-10-12 18:00:00                      London Eltham      pm25
# 3      2021-10-12 18:00:00             Tower Hamlets Roadside       no2
# 4      2021-10-12 18:00:00                      London Eltham       no2
# 5      2021-10-12 18:00:00                  London Harlington      pm10
# ...                    ...                                ...       ...
# 36973  2021-09-28 16:00:00  London Haringey Priory Park South       no2
# 36979  2021-09-28 16:00:00  London Haringey Priory Park South        o3
# 36982  2021-09-28 16:00:00                      London Eltham      pm10
# 36984  2021-09-28 16:00:00                           Thurrock       no2
# 37014  2021-09-28 16:00:00                           Thurrock       so2
#
#        value                    unit country    city  \
# ...

# %%
London_co = London[London['parameter'] == 'co'] 
London_o3 = London[London['parameter'] == 'o3'] 
London_pm10 = London[London['parameter'] == 'pm10'] 
London_pm25 = London[London['parameter'] == 'pm25'] 
London_so2 = London[London['parameter'] == 'so2']

# %%
sns.relplot(
    data = London, x="datetime", y="value", col="location",
    hue = "parameter", kind="line", 
    height=10, aspect=1
)

# %% [markdown]
# ## Question 5: Is there any relationship between levels of PM25 and PM10 in London?

# %%
### response: they are strongly correlated

# %%
data1 = London [London['parameter'] == 'pm10']

# %%
data1
# Out:
#                 date.local           location parameter  value  \
# 1      2021-10-12 18:00:00    Southend-on-Sea      pm10   14.0
# 5      2021-10-12 18:00:00  London Harlington      pm10   17.0
# 8      2021-10-12 18:00:00      London Eltham      pm10   13.0
# 11     2021-10-12 18:00:00           Thurrock      pm10   24.0
# 25     2021-10-12 17:00:00      London Eltham      pm10   13.0
# ...                    ...                ...       ...    ...
# 36469  2021-09-28 17:00:00    Southend-on-Sea      pm10    9.0
# 36591  2021-09-28 17:00:00      London Eltham      pm10    7.0
# 36900  2021-09-28 16:00:00    Southend-on-Sea      pm10    9.0
# 36965  2021-09-28 16:00:00           Thurrock      pm10   11.0
# 36982  2021-09-28 16:00:00      London Eltham      pm10    7.0
#
#                          unit country    city                   date.utc  \
# 1      b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-10-12 17:00:00+00:00
# ...

# %%
data2 = London [London['parameter'] == 'pm10']

# %%
data2
# Out:
#                 date.local           location parameter  value  \
# 1      2021-10-12 18:00:00    Southend-on-Sea      pm10   14.0
# 5      2021-10-12 18:00:00  London Harlington      pm10   17.0
# 8      2021-10-12 18:00:00      London Eltham      pm10   13.0
# 11     2021-10-12 18:00:00           Thurrock      pm10   24.0
# 25     2021-10-12 17:00:00      London Eltham      pm10   13.0
# ...                    ...                ...       ...    ...
# 36469  2021-09-28 17:00:00    Southend-on-Sea      pm10    9.0
# 36591  2021-09-28 17:00:00      London Eltham      pm10    7.0
# 36900  2021-09-28 16:00:00    Southend-on-Sea      pm10    9.0
# 36965  2021-09-28 16:00:00           Thurrock      pm10   11.0
# 36982  2021-09-28 16:00:00      London Eltham      pm10    7.0
#
#                          unit country    city                   date.utc  \
# 1      b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-10-12 17:00:00+00:00
# ...

# %%
df = pd.merge (data1, data2, how = 'left', left_on = 'datetime', right_on = 'datetime')

# %%
df
# Out:
#              date.local_x         location_x parameter_x  value_x  \
# 0     2021-10-12 18:00:00    Southend-on-Sea        pm10     14.0
# 1     2021-10-12 18:00:00    Southend-on-Sea        pm10     14.0
# 2     2021-10-12 18:00:00    Southend-on-Sea        pm10     14.0
# 3     2021-10-12 18:00:00    Southend-on-Sea        pm10     14.0
# 4     2021-10-12 18:00:00  London Harlington        pm10     17.0
# ...                   ...                ...         ...      ...
# 4251  2021-09-28 16:00:00           Thurrock        pm10     11.0
# 4252  2021-09-28 16:00:00           Thurrock        pm10     11.0
# 4253  2021-09-28 16:00:00      London Eltham        pm10      7.0
# 4254  2021-09-28 16:00:00      London Eltham        pm10      7.0
# 4255  2021-09-28 16:00:00      London Eltham        pm10      7.0
#
#                       unit_x country_x  city_x                 date.utc_x  \
# 0     b'\xc2\xb5g/m\xc2\xb3'        GB  London  2021-10-12 17:00:00+00:00
# ...

# %%
pm25vspm10 = sns.kdeplot (x = df['value_x'],
                          y = df['value_y'], shape = True
                         )
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:1182: UserWarning: The following kwargs were not used by contour: 'shape'
#   cset = contour_func(

# %% [markdown]
# # My findings, PM25 and PM10 are strongly correlated
